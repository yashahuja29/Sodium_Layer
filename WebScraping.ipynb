# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin

# Define the URL of the website you want to download images from
website_url = "https://www.isee.nagoya-u.ac.jp/~nozawa/LIDAR/2010LIDARpnghp/index.html"

# Send an HTTP GET request to the website
response = requests.get(website_url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Create a directory to save the downloaded images
    os.makedirs("downloaded_images", exist_ok=True)

    # Find all image tags in the HTML
    img_tags = soup.find_all('img')

    # Download each image
    for img in img_tags:
        img_url = img.get('src')
        if not img_url:
            continue

        # Ensure that the URL is absolute (join with the base URL if it's relative)
        img_url = urljoin(website_url, img_url)

        # Get the filename from the URL
        img_filename = os.path.basename(urlparse(img_url).path)

        # Download the image
        img_response = requests.get(img_url)
        if img_response.status_code == 200:
            with open(os.path.join("downloaded_images", img_filename), 'wb') as img_file:
                img_file.write(img_response.content)
                print(f"Downloaded: {img_filename}")
        else:
            print(f"Failed to download: {img_url}")

else:
    print(f"Failed to access the website. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[2], line 38
#      36 img_response = requests.get(img_url)
#      37 if img_response.status_code == 200:
# ---> 38     with open(os.path.join("downloaded_images", img_filename), 'wb') as img_file:
#      39         img_file.write(img_response.content)
#      40         print(f"Downloaded: {img_filename}")
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# ...

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin
import uuid

# Define the URL of the website you want to download images from
website_url = "https://www.isee.nagoya-u.ac.jp/~nozawa/LIDAR/lidarpng2012_60min_75bin.html"

# Send an HTTP GET request to the website
response = requests.get(website_url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Create a directory to save the downloaded images
    os.makedirs("downloaded_images", exist_ok=True)

    # Find all image tags in the HTML
    img_tags = soup.find_all('img')

    # Download each image
    for img in img_tags:
        img_url = img.get('src')
        if not img_url:
            continue

        # Ensure that the URL is absolute (join with the base URL if it's relative)
        img_url = urljoin(website_url, img_url)

        # Generate a unique filename using a UUID
        img_filename = str(uuid.uuid4()) + os.path.splitext(urlparse(img_url).path)[1]

        # Download the image
        img_response = requests.get(img_url)
        if img_response.status_code == 200:
            with open(os.path.join("downloaded_images", img_filename), 'wb') as img_file:
                img_file.write(img_response.content)
                print(f"Downloaded: {img_filename}")
        else:
            print(f"Failed to download: {img_url}")

else:
    print(f"Failed to access the website. Status code: {response.status_code}")
# Out:
# Downloaded: 95ee3cd6-9684-4c50-aeae-c1d1c13e653b

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin

# Define the URL of the webpage containing image hyperlinkshhttps://www.isee.nagoya-u.ac.jp/~nozawa/LIDAR/lidarpng2012_60min_75bin.html"  # Replace
webpage_url = " with the URL of your webpage

# Send an HTTP GET request to the webpage
response = requests.get(webpage_url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the webpage
    soup = BeautifulSoup(response.text, 'html.parser')

    # Create a directory to save the downloaded images
    os.makedirs("downloaded_images", exist_ok=True)

    # Find all hyperlinks (anchor tags) in the HTML
    links = soup.find_all('a')

    # Filter the links to get only those that point to image files
    image_links = [link.get('href') for link in links if link.get('href') and link.get('href').lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

    # Download each image
    for img_url in image_links:
        # Ensure that the URL is absolute (join with the base URL if it's relative)
        img_url = urljoin(webpage_url, img_url)

        # Get the filename from the URL
        img_filename = os.path.basename(urlparse(img_url).path)

        # Download the image
        img_response = requests.get(img_url)
        if img_response.status_code == 200:
            with open(os.path.join("downloaded_images", img_filename), 'wb') as img_file:
                img_file.write(img_response.content)
                print(f"Downloaded: {img_filename}")
        else:
            print(f"Failed to download: {img_url}")

else:
    print(f"Failed to access the webpage. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-2-11d1b98ae7e8> in <cell line: 10>()
#       8
#       9 # Send an HTTP GET request to the webpage
# ---> 10 response = requests.get(webpage_url)
#      11
#      12 # Check if the request was successful
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...

# %%
import zipfile

def zip_file(input_file_path, output_zip_path):
    with zipfile.ZipFile(output_zip_path, 'w') as zip_file:
        zip_file.write(input_file_path, arcname=os.path.basename(input_file_path))

# Example usage:
input_file_path = '/content/downloaded_images'
output_zip_path = '/content'

zip_file(input_file_path, output_zip_path)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-5-e1b343100563> in <cell line: 11>()
#       9 output_zip_path = '/content'
#      10
# ---> 11 zip_file(input_file_path, output_zip_path)
#
# <ipython-input-5-e1b343100563> in zip_file(input_file_path, output_zip_path)
#       2
#       3 def zip_file(input_file_path, output_zip_path):
# ----> 4     with zipfile.ZipFile(output_zip_path, 'w') as zip_file:
#       5         zip_file.write(input_file_path, arcname=os.path.basename(input_file_path))
#       6
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249             while True:
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#    1253                     if filemode in modeDict:
#
# ...

# %%
# !zip -r /content/file.zip /content/downloaded_images
# Out:
#   adding: content/downloaded_images/ (stored 0%)
#   adding: content/downloaded_images/201202211200_rx0_20min51bin.png (deflated 9%)
#   adding: content/downloaded_images/201112261200_rx0_20min51bin.png (deflated 3%)
#   adding: content/downloaded_images/201111211200_rx0_20min51bin.png (deflated 16%)
#   adding: content/downloaded_images/201112081200_rx0_20min51bin.png (deflated 2%)
#   adding: content/downloaded_images/201201291200_rx0_20min51bin.png (deflated 2%)
#   adding: content/downloaded_images/201111201200_rx0_20min51bin.png (deflated 8%)
#   adding: content/downloaded_images/201112221200_rx0_20min51bin.png (deflated 6%)
#   adding: content/downloaded_images/201201131200_rx0_20min51bin.png (deflated 3%)
#   adding: content/downloaded_images/201111281200_rx0_20min51bin.png (deflated 3%)
#   adding: content/downloaded_images/201112071200_rx0_20min51bin.png (deflated 2%)
#   adding: content/downloaded_images/201202151200_rx0_20min51bin.png (deflated 7%)
# ...
